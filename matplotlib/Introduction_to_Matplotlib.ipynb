# %% [markdown]
# # Introduction to Matplotlib

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.style.available
plt.style.use("seaborn-v0_8-whitegrid")

# %%
plt.plot()
# Out:
# []

# %%
x = [1, 2, 3, 4]
y = [10, 8, 6, 9]
plt.plot(
    x, y, color="red"
);  # put ; to remove [<matplotlib.lines.Line20 at 0x7f9c1c2e8d90>]

# %% [markdown]
# ## I. Pyplot API vs Object-Oriented (OO) API
# * Pyplot API →  Quickly
# * OO API → Advanced

# %% [markdown]
# ### 1. Pyplot API

# %%
x = np.linspace(0, 10, 1000)
plt.plot(x, np.sin(x), color="#662222", linestyle="dashed", label="sin(x)")
plt.plot(x, np.cos(x), color="blue", label="cos(x)")

plt.title("Sin(x) and Cos(x)")
plt.xlabel("X")
plt.ylabel("F(x)")

# plt.xlim([0, 4])
# plt.ylim([-0.6, 0.6])
# plt.axis((0, 4, -0.7, 0.6))  # (xmin, xmax, ymin, ymax)
# plt.axis("tight")
plt.axis("equal")

plt.legend();
# plt.show(); # just need run in terminal or python script

# %% [markdown]
# ### 2. Object-Oriented API

# %%
# 1. Prepare data
x = [1, 2, 3, 4]
y = [11, 22, 33, 44]

# 2. Setup plot
fig, ax = plt.subplots(figsize=(5, 5))  # Figure size = Width & Height of the plot

# 3. Plot the data
ax.plot(x, y)
ax.set(title="A simple plot", xlabel="X-axis", ylabel="y-axis");

# %% [markdown]
# ## II. Most common types of Matplotlib plots
# * line
# * scatter
# * bar
# * hist
# * subplots()
#
# ### 1. Line

# %%
# Create an array
x = np.linspace(0, 10, 100)

# %%
# OO API plt a line chart
fig, ax = plt.subplots()
ax.plot(x, x**3);

# %% [markdown]
# ### 2. Scatter

# %%
# Pylot API
plt.scatter(x, np.exp(x));  # y = e^(x)

# %%
# OO API

# Prepare new data
rng = np.random.RandomState(0)

x = rng.randn(100)
y = rng.randn(100)

colors = rng.rand(100)
sizes = 1000 * rng.rand(100)

fig, ax = plt.subplots()
img1 = ax.scatter(x, y, s=sizes, c=colors, cmap="viridis", alpha=0.3)
fig.colorbar(img1);

# %% [markdown]
# ### 3. Bar
# * Vertical
# * Horizontal

# %%
# Prepare Data from a python dictionary
soft_drink_prices = {"Coke": 10, "Pessi": 12, "Sprite": 8}

fig, ax = plt.subplots()
ax.bar(list(soft_drink_prices.keys()), list(soft_drink_prices.values()))
ax.set(title="BHX's Soft Drink Prices", ylabel="Price ($)");

# %%
fig, ax = plt.subplots()
ax.barh(list(soft_drink_prices.keys()), list(soft_drink_prices.values()))
ax.set(title="BHX's Soft Drink Prices", xlabel="Price ($)");

# %% [markdown]
# ### 4. Histogram

# %%
# Prepare Data
np.random.seed(42)
student_height = np.random.normal(170, 10, 250)

# %%
# Pylot API
plt.hist(student_height, bins=30);

# %% [markdown]
# ## III. Subplots
# * Multiple plots on one figure: https://matplotlib.org/3.1.1/gallery/recipes/create_subplots.html

# %%
# Option 1:
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2, ncols=2, figsize=(10, 5))

# Plot data to each axis
ax1.plot(x, x / 2)
ax1.plot(x, x * 2)

ax2.scatter(np.random.random(10), np.random.random(10))

ax3.bar(list(soft_drink_prices.keys()), list(soft_drink_prices.values()))

ax4.hist(student_height, bins=30);

# %%
# Option 2:
fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(10, 5))

ax[0, 0].plot(x, x / 2)
ax[0, 0].plot(x, x * 2)

ax[0, 1].scatter(np.random.random(10), np.random.random(10))

ax[1, 0].bar(list(soft_drink_prices.keys()), list(soft_drink_prices.values()))

ax[1, 1].hist(student_height, bins=30);
